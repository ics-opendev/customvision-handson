# %% [markdown]
# # Custom Vision に画像を追加する

# %% [markdown]
# Custom Vision SDK の パッケージをインポートします。

# %%
# !pip install azure-cognitiveservices-vision-customvision
# Out:
# Requirement already satisfied: azure-cognitiveservices-vision-customvision in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (3.1.0)
# Requirement already satisfied: azure-common~=1.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cognitiveservices-vision-customvision) (1.1.28)
# Requirement already satisfied: msrest>=0.5.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cognitiveservices-vision-customvision) (0.6.21)
# Requirement already satisfied: isodate>=0.6.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from msrest>=0.5.0->azure-cognitiveservices-vision-customvision) (0.6.1)
# Requirement already satisfied: requests~=2.16 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from msrest>=0.5.0->azure-cognitiveservices-vision-customvision) (2.27.1)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from msrest>=0.5.0->azure-cognitiveservices-vision-customvision) (2022.5.18.1)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from msrest>=0.5.0->azure-cognitiveservices-vision-customvision) (1.3.1)
# Requirement already satisfied: six in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from isodate>=0.6.0->msrest>=0.5.0->azure-cognitiveservices-vision-customvision) (1.16.0)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from requests~=2.16->msrest>=0.5.0->azure-cognitiveservices-vision-customvision) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from requests~=2.16->msrest>=0.5.0->azure-cognitiveservices-vision-customvision) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from requests~=2.16->msrest>=0.5.0->azure-cognitiveservices-vision-customvision) (3.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.5.0->azure-cognitiveservices-vision-customvision) (3.2.0)

# %% [markdown]
# スクリプトの実行に必要なパッケージをインポートします。

# %%
from azure.cognitiveservices.vision.customvision.training import CustomVisionTrainingClient
from azure.cognitiveservices.vision.customvision.training.models import ImageFileCreateEntry
from azure.cognitiveservices.vision.customvision.training.models import ImageFileCreateBatch
from msrest.authentication import ApiKeyCredentials 
import numpy as np

# %% [markdown]
# 自分のリソースの Azure エンドポイントおよびキー用の変数を作成します

# %%
# Replace with valid values
ENDPOINT = 'https://cvtakahashihandsonjpeast001.cognitiveservices.azure.com/'
training_key = 'f138fa8bda544d94897cc4a794de4141'
project_name = 'takahashi-project-001'

# %% [markdown]
# ## クライアントを認証する
#
# エンドポイントとキーを使用してトレーニングのクライアントをインスタンス化します。
#
# ドキュメント
# [CustomVisionTrainingClient](https://docs.microsoft.com/ja-JP/python/api/azure-cognitiveservices-vision-customvision/azure.cognitiveservices.vision.customvision.training.customvisiontrainingclient?view=azure-python)

# %%
credentials = ApiKeyCredentials(in_headers={'Training-key': training_key})
trainer = CustomVisionTrainingClient(ENDPOINT, credentials)

# %%
def printMethod(obj):
    print(type(obj))
    for x in dir(obj):
        print(x, ':', type(eval('obj.'+x)))

# %%
# プロジェクト一覧を取得
projects = trainer.get_projects()

# 今回のプロジェクト
target_project = None

for pj in projects:
    if pj.name == project_name:
        target_project = pj

# %%
import os

# 鳥のタグの一覧を取得します。 タグは、ディレクトリのフォルダー名に基づいて作成します。
tags_name = [name for name in os.listdir('datasets')]
print(tags_name)
# Out:
# ['American Crow', 'American Goldfinch (Female)', 'American Goldfinch (Male)', 'American Robin (Adult)', 'American Robin (Juvenile)', 'Blue Jay', 'Common Grackle', 'House Sparrow (Female)', 'House Sparrow (Male)', 'House Wren', 'Mourning Dove', 'Northern Cardinal (Adult Male)', 'Northern Cardinal (Female)', 'Red-tailed Hawk (Dark morph)', 'Red-tailed Hawk (Light morph immature)', 'Tufted Titmouse']

# %%
# Custom Vision プロジェクトにタグの作成もしくは取得が行われます。
def find_or_create_tag(project, tag_name):
    # 存在チェック
    for existing_tag in trainer.get_tags(project.id):
        if existing_tag.name == tag_name:
            return existing_tag.id

    # 新規作成
    result = trainer.create_tag(project.id, tag_name)
    print(f'{tag_name} を作成しました : {result}')
    return result.id

# %%
# タグ名とタグ ID を使用して画像のリストが作成されます。
def create_image_list(tag_name, tag_id):
    base_image_url = f"./datasets/{tag_name}/"
    photo_name_list = os.listdir(base_image_url)
    image_list = []
    for file_name in photo_name_list:
        with open(base_image_url+file_name, "rb") as image_contents:
            image_list.append(ImageFileCreateEntry(name=base_image_url+file_name, contents=image_contents.read(), tag_ids=[tag_id]))
    return image_list

# %% [markdown]
# ドキュメント [create_images_from_files](https://docs.microsoft.com/en-us/python/api/azure-cognitiveservices-vision-customvision/azure.cognitiveservices.vision.customvision.training.operations.customvisiontrainingclientoperationsmixin?view=azure-python#azure-cognitiveservices-vision-customvision-training-operations-customvisiontrainingclientoperationsmixin-create-images-from-files)

# %%
def uploadImageList(project, images_batch):
    upload_result = trainer.create_images_from_files(project.id, batch=images_batch)
    if not upload_result.is_batch_successful:
        print("画像のアップロードに失敗しました.")
        for image in upload_result.images:
            print("ステータス: ", image.status)
        exit(-1)

# %%
# 画像を登録
for tag_name in tags_name:
    # タグを取得
    tag_id = find_or_create_tag(target_project, tag_name)
    # 送信する画像をリスト化
    image_list = create_image_list(tag_name, tag_id)
    print(f"{tag_name} の image_listを作成しました 合計: " + str(len(image_list)))

    # 64枚ずつ送信する(APIの上限)
    for i in range(0, len(image_list), 64):
        images_batch = ImageFileCreateBatch(images=image_list[i:i + 64])
        print(f'{tag_name} の {len(images_batch.images)}枚の画像を送信開始')
        uploadImageList(target_project, images_batch)
        print(f'{tag_name} の 送信完了')
# Out:
# American Crow の image_listを作成しました 合計: 117
# American Crow の 64枚の画像を送信開始
# American Crow の 送信完了
# American Crow の 53枚の画像を送信開始
# American Crow の 送信完了
# American Goldfinch (Female) を作成しました : {'additional_properties': {}, 'id': '9ad936e5-b327-43ed-97a3-a600628b8b42', 'name': 'American Goldfinch (Female)', 'description': None, 'type': 'Regular', 'image_count': 0}
# American Goldfinch (Female) の image_listを作成しました 合計: 120
# American Goldfinch (Female) の 64枚の画像を送信開始
# American Goldfinch (Female) の 送信完了
# American Goldfinch (Female) の 56枚の画像を送信開始
# American Goldfinch (Female) の 送信完了
# American Goldfinch (Male) を作成しました : {'additional_properties': {}, 'id': 'ced97240-02e6-40c2-97a6-7504e4675c30', 'name': 'American Goldfinch (Male)', 'description': None, 'type': 'Regular', 'image_count': 0}
# American Goldfinch (Male) の image_listを作成しました 合計: 120
# American Goldfinch (Male) の 64枚の画像を送信開始
# American Goldfinch (Male) の 送信完了
# American Goldfinch (Male) の 56枚の画像を送信開始
# American Goldfinch (Male) の 送信完了
# American Robin (Adult) を作成しました : {'additional_properties': {}, 'id': '55ceb8c8-6af5-4fdf-bd40-4356851fd193', 'name': 'American Robin (Adult)', 'description': None, 'type': 'Regular', 'image_count': 0}
# American Robin (Adult) の image_listを作成しました 合計: 119
# American Robin (Adult) の 64枚の画像を送信開始
# American Robin (Adult) の 送信完了
# American Robin (Adult) の 55枚の画像を送信開始
# American Robin (Adult) の 送信完了
# American Robin (Juvenile) を作成しました : {'additional_properties': {}, 'id': 'cd9bc060-0f00-400d-a566-2667ba1db4de', 'name': 'American Robin (Juvenile)', 'description': None, 'type': 'Regular', 'image_count': 0}
# American Robin (Juvenile) の image_listを作成しました 合計: 115
# American Robin (Juvenile) の 64枚の画像を送信開始
# American Robin (Juvenile) の 送信完了
# American Robin (Juvenile) の 51枚の画像を送信開始
# American Robin (Juvenile) の 送信完了
# Blue Jay を作成しました : {'additional_properties': {}, 'id': '1e9069af-9825-4c5a-a90a-2bfb8538148d', 'name': 'Blue Jay', 'description': None, 'type': 'Regular', 'image_count': 0}
# Blue Jay の image_listを作成しました 合計: 120
# Blue Jay の 64枚の画像を送信開始
# Blue Jay の 送信完了
# Blue Jay の 56枚の画像を送信開始
# Blue Jay の 送信完了
# Common Grackle を作成しました : {'additional_properties': {}, 'id': '5c094880-86a6-4ed4-a85d-cce999cec7a9', 'name': 'Common Grackle', 'description': None, 'type': 'Regular', 'image_count': 0}
# Common Grackle の image_listを作成しました 合計: 118
# Common Grackle の 64枚の画像を送信開始
# Common Grackle の 送信完了
# Common Grackle の 54枚の画像を送信開始
# Common Grackle の 送信完了
# House Sparrow (Female) を作成しました : {'additional_properties': {}, 'id': 'f40448fb-9964-4878-9165-acae0ba7800e', 'name': 'House Sparrow (Female)', 'description': None, 'type': 'Regular', 'image_count': 0}
# House Sparrow (Female) の image_listを作成しました 合計: 117
# House Sparrow (Female) の 64枚の画像を送信開始
# House Sparrow (Female) の 送信完了
# House Sparrow (Female) の 53枚の画像を送信開始
# House Sparrow (Female) の 送信完了
# House Sparrow (Male) を作成しました : {'additional_properties': {}, 'id': '87a02e12-54a3-4e00-bc19-9f58b561155e', 'name': 'House Sparrow (Male)', 'description': None, 'type': 'Regular', 'image_count': 0}
# House Sparrow (Male) の image_listを作成しました 合計: 119
# House Sparrow (Male) の 64枚の画像を送信開始
# House Sparrow (Male) の 送信完了
# House Sparrow (Male) の 55枚の画像を送信開始
# House Sparrow (Male) の 送信完了
# House Wren を作成しました : {'additional_properties': {}, 'id': 'b2dc79b3-7cda-4283-aa24-58e59170f914', 'name': 'House Wren', 'description': None, 'type': 'Regular', 'image_count': 0}
# House Wren の image_listを作成しました 合計: 114
# House Wren の 64枚の画像を送信開始
# House Wren の 送信完了
# House Wren の 50枚の画像を送信開始
# House Wren の 送信完了
# Mourning Dove を作成しました : {'additional_properties': {}, 'id': 'f3bc9b05-dbb6-4b9d-a319-0cbbe7f0631b', 'name': 'Mourning Dove', 'description': None, 'type': 'Regular', 'image_count': 0}
# Mourning Dove の image_listを作成しました 合計: 120
# Mourning Dove の 64枚の画像を送信開始
# Mourning Dove の 送信完了
# Mourning Dove の 56枚の画像を送信開始
# Mourning Dove の 送信完了
# Northern Cardinal (Adult Male) を作成しました : {'additional_properties': {}, 'id': 'd96ecd13-280f-4f23-94b3-4155bae68a72', 'name': 'Northern Cardinal (Adult Male)', 'description': None, 'type': 'Regular', 'image_count': 0}
# Northern Cardinal (Adult Male) の image_listを作成しました 合計: 120
# Northern Cardinal (Adult Male) の 64枚の画像を送信開始
# Northern Cardinal (Adult Male) の 送信完了
# Northern Cardinal (Adult Male) の 56枚の画像を送信開始
# Northern Cardinal (Adult Male) の 送信完了
# Northern Cardinal (Female) を作成しました : {'additional_properties': {}, 'id': 'bc9a9dd2-55e6-47e8-9774-858c56cd66a6', 'name': 'Northern Cardinal (Female)', 'description': None, 'type': 'Regular', 'image_count': 0}
# Northern Cardinal (Female) の image_listを作成しました 合計: 120
# Northern Cardinal (Female) の 64枚の画像を送信開始
# Northern Cardinal (Female) の 送信完了
# Northern Cardinal (Female) の 56枚の画像を送信開始
# Northern Cardinal (Female) の 送信完了
# Red-tailed Hawk (Dark morph) を作成しました : {'additional_properties': {}, 'id': '5e8a9fe9-ad30-4afd-959e-c5a6b0a797fa', 'name': 'Red-tailed Hawk (Dark morph)', 'description': None, 'type': 'Regular', 'image_count': 0}
# Red-tailed Hawk (Dark morph) の image_listを作成しました 合計: 58
# Red-tailed Hawk (Dark morph) の 58枚の画像を送信開始
# Red-tailed Hawk (Dark morph) の 送信完了
# Red-tailed Hawk (Light morph immature) を作成しました : {'additional_properties': {}, 'id': '5e461490-0880-421d-96c9-2826cf369133', 'name': 'Red-tailed Hawk (Light morph immature)', 'description': None, 'type': 'Regular', 'image_count': 0}
# Red-tailed Hawk (Light morph immature) の image_listを作成しました 合計: 120
# Red-tailed Hawk (Light morph immature) の 64枚の画像を送信開始
# Red-tailed Hawk (Light morph immature) の 送信完了
# Red-tailed Hawk (Light morph immature) の 56枚の画像を送信開始
# Red-tailed Hawk (Light morph immature) の 送信完了
# Tufted Titmouse を作成しました : {'additional_properties': {}, 'id': 'a233df0f-a962-4c3a-814b-89f37eb88578', 'name': 'Tufted Titmouse', 'description': None, 'type': 'Regular', 'image_count': 0}
# Tufted Titmouse の image_listを作成しました 合計: 120
# Tufted Titmouse の 64枚の画像を送信開始
# Tufted Titmouse の 送信完了
# Tufted Titmouse の 56枚の画像を送信開始
# Tufted Titmouse の 送信完了

# %% [markdown]
# ## トレーニング

# %%
import time

print ("Training...")
iteration = trainer.train_project(target_project.id, training_type='Regular')

while (iteration.status != "Completed"):
    iteration = trainer.get_iteration(target_project.id, iteration.id)
    print ("Training status: " + iteration.status)
    time.sleep(10)
# Out:
# Training...
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training

# %% [markdown]
# ## 操作に失敗した場合

# %%
# タグの全リセット
for existing_tag in trainer.get_tags(target_project.id):
    trainer.delete_tag(target_project.id, existing_tag.id)

# %%
# 画像の全削除
trainer.delete_images(target_project.id)
